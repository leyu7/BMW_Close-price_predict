#
#               Volume
# Date
# 2016-08-24  12853500
# 2016-08-25   8812500
# 2016-08-26  11195000
# 2016-08-29  16331500
# 2016-08-30  15844500
# ...              ...
# 2021-08-17  23721300
# 2021-08-18  20349400
# 2021-08-19  14313500
# 2021-08-20  14781800
# 2021-08-23  20069007
#
# [1258 rows x 6 columns]

# %%
nissian
# Out:
#                    Open         High         Low        Close   Adj Close  \
# Date
# 2016-08-24   961.500000   973.799988  955.299988   972.200012  826.390381
# 2016-08-25   976.000000   993.000000  969.099976   982.500000  835.145630
# 2016-08-26   980.000000   984.900024  972.000000   974.000000  827.920410
# 2016-08-29  1000.000000  1005.000000  996.400024  1001.000000  850.870972
# 2016-08-30   995.000000  1005.500000  988.200012  1003.000000  852.570984
# ...                 ...          ...         ...          ...         ...
# 2021-08-18   579.900024   584.099976  574.400024   581.000000  581.000000
# 2021-08-19   575.599976   578.099976  565.700012   565.700012  565.700012
# 2021-08-20   555.700012   562.599976  521.599976   524.700012  524.700012
# 2021-08-23   534.700012   550.000000  533.500000   542.599976  542.599976
# 2021-08-24   546.299988   562.799988  546.299988   561.000000  561.000000
#
#               Volume
# Date
# 2016-08-24  14245400
# 2016-08-25  15255800
# 2016-08-26  13899600
# 2016-08-29  15360000
# 2016-08-30  11450800
# ...              ...
# 2021-08-18   9634500
# 2021-08-19  10937400
# 2021-08-20  33269400
# 2021-08-23  16013400
# 2021-08-24   7874700
#
# [1241 rows x 6 columns]

# %%
honda
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2016-08-24  30.670000  30.770000  30.540001  30.600000  30.600000   459100
# 2016-08-25  30.580000  30.660000  30.530001  30.620001  30.620001   411300
# 2016-08-26  30.219999  30.420000  29.959999  30.230000  30.230000   990200
# 2016-08-29  30.520000  30.719999  30.500000  30.620001  30.620001   521800
# 2016-08-30  30.879999  30.980000  30.830000  30.900000  30.900000   497600
# ...               ...        ...        ...        ...        ...      ...
# 2021-08-17  32.119999  32.160000  31.590000  31.780001  31.780001   510900
# 2021-08-18  31.889999  31.889999  31.530001  31.559999  31.559999   451800
# 2021-08-19  31.000000  31.010000  30.639999  30.740000  30.740000   578600
# 2021-08-20  30.000000  30.150000  29.750000  29.799999  29.799999  1974300
# 2021-08-23  30.120001  30.200001  29.809999  30.110001  30.110001   616170
#
# [1258 rows x 6 columns]

# %% [markdown]
# ## Other stock price

# %%
# import pandas_datareader.data as pdr
# import yfinance as yf

# %%
# yf.pdr_override()
# CATL_code='300750.sz'   # 深股 宁德时代
# INOVANCE_code='300124.sz'   # 深股 汇川技术
# cat=pdr.get_data_yahoo(CATL_code,'2016-08-24','2021-08-23')
# ino=pdr.get_data_yahoo(INOVANCE_code,'2016-08-24','2021-08-23')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# cat.to_csv('./data/CATL.csv')
# ino.to_csv('./data/INOVANCE.csv')

# %%
# CATL = loadData('CATL')
# CATL
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 
# 2021-08-19  4405.799805
# 2021-08-20  4441.669922
# 2021-08-23  4479.529785
#
# [1259 rows x 6 columns]

# %%
# import tushare as ts

# CSI300 = ts.get_k_data('hs300', start='2016-08-24',
#                        end='2021-08-23').reset_index(drop=True)
# CSI300
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://waditu.com/document/2
#             date     open    close     high      low       volume   code
# 0     2016-08-24  3341.93  3329.86  3348.13  3323.73   81191429.0  hs300
# 1     2016-08-25  3314.08  3308.97  3315.08  3279.81  100589153.0  hs300
# 2     2016-08-26  3312.50  3307.09  3328.95  3301.74   81530691.0  hs300
# 3     2016-08-29  3306.57  3307.78  3315.08  3297.07   77036333.0  hs300
# 4     2016-08-30  3310.32  3311.99  3325.12  3304.60   75725987.0  hs300
# ...          ...      ...      ...      ...      ...          ...    ...
# 1211  2021-08-17  4935.00  4837.40  4967.56  4823.39  187573472.0  hs300
# 1212  2021-08-18  4838.47  4894.24  4909.54  4818.90  197474378.0  hs300
# 1213  2021-08-19  4886.56  4862.14  4893.47  4839.57  201711719.0  hs300
# 1214  2021-08-20  4817.49  4769.27  4835.15  4720.83  177635810.0  hs300
# 1215  2021-08-23  4777.73  4835.88  4843.82  4764.01  167579093.0  hs300
#
# [1216 rows x 7 columns]

# %%
# CSI300 = CSI300.iloc[:, :-1]
# for name in CSI300.columns:
#     CSI300 = CSI300.rename(columns={name: name.title()})

# %%
# csi300 = CSI300.copy().set_index('Date')
# csi300
# Out:
#                Open    Close     High      Low       Volume
# Date
# 2016-08-24  3341.93  3329.86  3348.13  3323.73   81191429.0
# 2016-08-25  3314.08  3308.97  3315.08  3279.81  100589153.0
# 2016-08-26  3312.50  3307.09  3328.95  3301.74   81530691.0
# 2016-08-29  3306.57  3307.78  3315.08  3297.07   77036333.0
# 2016-08-30  3310.32  3311.99  3325.12  3304.60   75725987.0
# ...             ...      ...      ...      ...          ...
# 2021-08-17  4935.00  4837.40  4967.56  4823.39  187573472.0
# 2021-08-18  4838.47  4894.24  4909.54  4818.90  197474378.0
# 2021-08-19  4886.56  4862.14  4893.47  4839.57  201711719.0
# 2021-08-20  4817.49  4769.27  4835.15  4720.83  177635810.0
# 2021-08-23  4777.73  4835.88  4843.82  4764.01  167579093.0
#
# [1216 rows x 5 columns]

# %%
# csi300.to_csv('./data/CSI300.csv')

# %%
CSI300 = loadData('CSI300')
CSI300
# Out:
#                Open    Close     High      Low       Volume
# Date
# 2016-08-24  3341.93  3329.86  3348.13  3323.73   81191429.0
# 2016-08-25  3314.08  3308.97  3315.08  3279.81  100589153.0
# 2016-08-26  3312.50  3307.09  3328.95  3301.74   81530691.0
# 2016-08-29  3306.57  3307.78  3315.08  3297.07   77036333.0
# 2016-08-30  3310.32  3311.99  3325.12  3304.60   75725987.0
# ...             ...      ...      ...      ...          ...
# 2021-08-17  4935.00  4837.40  4967.56  4823.39  187573472.0
# 2021-08-18  4838.47  4894.24  4909.54  4818.90  197474378.0
# 2021-08-19  4886.56  4862.14  4893.47  4839.57  201711719.0
# 2021-08-20  4817.49  4769.27  4835.15  4720.83  177635810.0
# 2021-08-23  4777.73  4835.88  4843.82  4764.01  167579093.0
#
# [1216 rows x 5 columns]

# %% [markdown]
# # Preparation

# %%
# Column Name Change
def name_change(df, df_name):
    for name in df.columns:
        df = df.rename(columns = {name: (df_name +"_"+ name)})
    return df

# %%
Volkswagen = name_change(Volkswagen, "Volkswagen")
bmw = name_change(bmw, "bmw")
tesla = name_change(tesla, "tesla")
nissian = name_change(nissian, "nissian")
honda = name_change(honda, "honda")
# CATL = name_change(CATL, "CATL")
# INOVANCE = name_change(INOVANCE, "INOVANCE")
sp500 = name_change(sp500, "SP500")
CSI300 = name_change(CSI300, "CSI300")

# %%
CSI300
# Out:
#             CSI300_Open  CSI300_Close  CSI300_High  CSI300_Low  CSI300_Volume
# Date
# 2016-08-24      3341.93       3329.86      3348.13     3323.73     81191429.0
# 2016-08-25      3314.08       3308.97      3315.08     3279.81    100589153.0
# 2016-08-26      3312.50       3307.09      3328.95     3301.74     81530691.0
# 2016-08-29      3306.57       3307.78      3315.08     3297.07     77036333.0
# 2016-08-30      3310.32       3311.99      3325.12     3304.60     75725987.0
# ...                 ...           ...          ...         ...            ...
# 2021-08-17      4935.00       4837.40      4967.56     4823.39    187573472.0
# 2021-08-18      4838.47       4894.24      4909.54     4818.90    197474378.0
# 2021-08-19      4886.56       4862.14      4893.47     4839.57    201711719.0
# 2021-08-20      4817.49       4769.27      4835.15     4720.83    177635810.0
# 2021-08-23      4777.73       4835.88      4843.82     4764.01    167579093.0
#
# [1216 rows x 5 columns]

# %%
def mergeData(datas):
    total_d = pd.DataFrame()
    for data in datas:
        if total_d.shape[0]==0:
            total_d = data
        else:
            total_d = total_d.join(data)
    return total_d

# %%
DATA = mergeData([bmw, Volkswagen, tesla, nissian, honda, sp500, CSI300])
DATA
# Out:
#              bmw_Open   bmw_High    bmw_Low  bmw_Close  bmw_Adj Close  \
# Date
# 2016-08-24  77.250000  78.029999  76.690002  77.510002      61.236576
# 2016-08-25  76.800003  76.839996  75.599998  76.220001      60.217419
# 2016-08-26  76.099998  77.290001  75.820000  77.230003      61.015369
# 2016-08-29  76.709999  77.230003  76.070000  76.879997      60.738838
# 2016-08-30  77.440002  78.559998  77.110001  78.459999      61.987129
# ...               ...        ...        ...        ...            ...
# 2021-08-17  81.000000  81.199997  80.190002  80.349998      80.349998
# 2021-08-18  80.519997  80.519997  78.940002  79.849998      79.849998
# 2021-08-19  77.349998  78.449997  77.080002  77.430000      77.430000
# 2021-08-20  77.000000  77.089996  75.410004  76.980003      76.980003
# 2021-08-23  78.239998  78.480003  76.570000  76.800003      76.800003
#
#             bmw_Volume  Volkswagen_Open  Volkswagen_High  Volkswagen_Low  \
# Date
# 2016-08-24      971047       123.050003       123.900002      121.150002
# 2016-08-25     1490961       122.050003       122.400002      119.449997
# 2016-08-26     1476195       120.699997       124.250000      120.550003
# 2016-08-29      708241       123.199997       124.900002      121.849998
# 2016-08-30     1213735       123.250000       125.250000      122.800003
# ...                ...              ...              ...             ...
# 2021-08-17     1033666       202.500000       202.649994      200.149994
# 2021-08-18     1366350       201.100006       201.300003      195.779999
errdf = pd.DataFrame(index=[
    'Simple Imputer', 'linear', 'nearest', 'zero', 'slinear', 'quadratic',
    'cubic', 'previous', 'next'],
                     columns=[cols])
errdf
# Out:
#                honda_Low SP500_High SP500_Close honda_Close honda_Adj Close  \
# Simple Imputer       NaN        NaN         NaN         NaN             NaN
# linear               NaN        NaN         NaN         NaN             NaN
# nearest              NaN        NaN         NaN         NaN             NaN
# zero                 NaN        NaN         NaN         NaN             NaN
# slinear              NaN        NaN         NaN         NaN             NaN
# quadratic            NaN        NaN         NaN         NaN             NaN
# cubic                NaN        NaN         NaN         NaN             NaN
# previous             NaN        NaN         NaN         NaN             NaN
# next                 NaN        NaN         NaN         NaN             NaN
#
#                tesla_Close CSI300_Open tesla_Open tesla_Adj Close bmw_Open
# Simple Imputer         NaN         NaN        NaN             NaN      NaN
# linear                 NaN         NaN        NaN             NaN      NaN
# nearest                NaN         NaN        NaN             NaN      NaN
# zero                   NaN         NaN        NaN             NaN      NaN
# slinear                NaN         NaN        NaN             NaN      NaN
# quadratic              NaN         NaN        NaN             NaN      NaN
# cubic                  NaN         NaN        NaN             NaN      NaN
# previous               NaN         NaN        NaN             NaN      NaN
# next                   NaN         NaN        NaN             NaN      NaN

# %%
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from scipy.interpolate import interp1d

def m_s_e(name):
    df_orig0 = pd.DataFrame(DATA[name].dropna())
    df0=df_orig0.sample(n=int(df_orig0.shape[0]*0.8), frac=None, replace=False, weights=None, random_state=41, axis=0).rename(columns={name: 'value'})
    dfdf = mergeData([df_orig0,df0])
    df_orig = pd.DataFrame(dfdf[name]).rename(columns={name: 'value'})
    df = pd.DataFrame(dfdf['value'])

    # Simple Imputer
    df_imput = SimpleImputer().fit_transform(df)
    err_imp = np.round(mean_squared_error(df_orig['value'], df_imput), 2)
    errdf.loc['Simple Imputer',name]=err_imp

    # Interpolation
    parameters = ['linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'previous', 'next']
    df['rownum'] = np.arange(df.shape[0])
    df_nona = df.dropna(subset=['value'])
    for param in parameters:
        f = interp1d(df_nona['rownum'], df_nona['value'], kind=param)
        df[param + '_fill'] = f(df['rownum'])
        error = np.round(mean_squared_error(df_orig['value'], df[param + '_fill']), 2)
        errdf.loc[param,name]=error
    return errdf

# Interpolation References:
# https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html
# https://docs.scipy.org/doc/scipy/reference/interpolate.html

# %%
for name in cols:
    m_s_e(name)
errdf
# Out:
#                honda_Low SP500_High SP500_Close honda_Close honda_Adj Close  \
# Simple Imputer       1.9   67360.05    67009.95         1.9             1.9
# linear              0.01      68.38      152.71        0.01            0.01
# nearest             0.03     156.36      292.04        0.03            0.03
# zero                0.04     159.27      300.37        0.04            0.04
# slinear             0.01      68.38      152.71        0.01            0.01
# quadratic           0.02      95.12      245.92        0.02            0.02
# cubic               0.02      98.89      269.84        0.02            0.02
# previous            0.04     159.27      300.37        0.04            0.04
# next                0.04     198.18      249.62        0.04            0.04
#
#                tesla_Close CSI300_Open tesla_Open tesla_Adj Close bmw_Open
# Simple Imputer    11960.28    86523.97   12098.58        11960.28    24.68
# linear               20.87      306.08      24.51           20.87     0.17
# nearest              38.39      474.54      38.01           38.39     0.29
# zero                  38.4      509.66      42.01            38.4     0.38
# slinear              20.87      306.08      24.51           20.87     0.17
# quadratic            18.76       437.1       30.7           18.76      0.2
# cubic                19.18      476.34       32.8           19.18     0.21
# previous              38.4      509.66      42.01            38.4     0.38
# next                 52.02      603.78      54.93           52.02     0.29

# %%
for n in errdf.columns:
    print(errdf[n].astype(float).idxmin())
# Out:
# linear
# linear
# linear
# linear
# linear
# quadratic
# linear
# linear
# quadratic
# linear

# %% [markdown]
# ### So we choose 'Linear Interpolation'

# %%
def linear_inter(df, col_name):
    df['rownum'] = np.arange(df.shape[0])
    df_nona = df.dropna(subset = [col_name])
    f = interp1d(df_nona['rownum'], df_nona[col_name])
    df[col_name] = f(df['rownum'])
    return df

# %%
DATA_L = DATA.copy()
DATA_L
# Out:
#              bmw_Open   bmw_High    bmw_Low  bmw_Close  bmw_Adj Close  \
# Date
# 2016-08-24  77.250000  78.029999  76.690002  77.510002      61.236576
# 2016-08-25  76.800003  76.839996  75.599998  76.220001      60.217419
# 2016-08-26  76.099998  77.290001  75.820000  77.230003      61.015369
# 2016-08-29  76.709999  77.230003  76.070000  76.879997      60.738838
# 2016-08-30  77.440002  78.559998  77.110001  78.459999      61.987129
# ...               ...        ...        ...        ...            ...
# 2021-08-17  81.000000  81.199997  80.190002  80.349998      80.349998
# 2021-08-18  80.519997  80.519997  78.940002  79.849998      79.849998
# 2021-08-19  77.349998  78.449997  77.080002  77.430000      77.430000
# 2021-08-20  77.000000  77.089996  75.410004  76.980003      76.980003
# 2021-08-23  78.239998  78.480003  76.570000  76.800003      76.800003
#
#             bmw_Volume  Volkswagen_Open  Volkswagen_High  Volkswagen_Low  \
# Date
# 2016-08-24      971047       123.050003       123.900002      121.150002
# 2016-08-25     1490961       122.050003       122.400002      119.449997
# 2016-08-26     1476195       120.699997       124.250000      120.550003
# 2016-08-29      708241       123.199997       124.900002      121.849998
# 2016-08-30     1213735       123.250000       125.250000      122.800003
# ...                ...              ...              ...             ...
# 2021-08-17     1033666       202.500000       202.649994      200.149994
# 2021-08-18     1366350       201.100006       201.300003      195.779999
# 2021-08-19     1743934       194.199997       195.800003      192.600006
# 2021-08-20     1731505       193.360001       193.360001      190.500000
# 2021-08-23     1640966       196.000000       196.000000      193.500000
#
#             Volkswagen_Close  ...    SP500_Low   SP500_Open  SP500_Close  \
# Date                          ...
# 2016-08-24        122.650002  ...  2171.250000  2185.090088  2175.439941
# 2016-08-25        120.400002  ...  2169.739990  2173.290039  2172.469971
# 2016-08-26        124.199997  ...  2160.389893  2175.100098  2169.040039
# 2016-08-29        122.400002  ...  2170.189941  2170.189941  2180.379883
# 2016-08-30        124.800003  ...  2170.409912  2179.449951  2176.120117
# ...                      ...  ...          ...          ...          ...
# 2021-08-17        200.300003  ...  4417.830078  4462.120117  4448.080078
# 2021-08-18        198.539993  ...  4397.589844  4440.939941  4400.270020
# 2021-08-19        194.839996  ...  4367.729980  4382.439941  4405.799805
# SP500_Adj Close         False
# CSI300_Open             False
# CSI300_Close            False
# CSI300_High             False
# CSI300_Low              False
# CSI300_Volume           False
# dtype: bool

# %% [markdown]
# ## Target and Label

# %%
x = DATA_L.loc[:, DATA_L.columns != 'bmw_Close'].values
x
# Out:
# array([[7.72500000e+01, 7.80299990e+01, 7.66900020e+01, ...,
#         3.34813000e+03, 3.32373000e+03, 8.11914290e+07],
#        [7.68000030e+01, 7.68399960e+01, 7.55999980e+01, ...,
#         3.31508000e+03, 3.27981000e+03, 1.00589153e+08],
#        [7.60999980e+01, 7.72900010e+01, 7.58200000e+01, ...,
#         3.32895000e+03, 3.30174000e+03, 8.15306910e+07],
#        ...,
#        [7.73499980e+01, 7.84499970e+01, 7.70800020e+01, ...,
#         4.89347000e+03, 4.83957000e+03, 2.01711719e+08],
#        [7.70000000e+01, 7.70899960e+01, 7.54100040e+01, ...,
#         4.83515000e+03, 4.72083000e+03, 1.77635810e+08],
#        [7.82399980e+01, 7.84800030e+01, 7.65700000e+01, ...,
#         4.84382000e+03, 4.76401000e+03, 1.67579093e+08]])

# %%
x.shape
# Out:
# (1266, 40)

# %%
y = DATA_L.bmw_Close.values
y
# Out:
# array([77.510002, 76.220001, 77.230003, ..., 77.43    , 76.980003,
#        76.800003])

# %% [markdown]
# ## GridSearchCV

# %%
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV

ts_cv = TimeSeriesSplit(n_splits=5)

# %%
import xgboost as xgb

xgb_model = xgb.XGBRegressor()
param_grid = {
    'max_depth': [7, 9, 11, 13],
    'n_estimators': [300, 500, 700],
    'learning_rate': [0.1, 0.01],
    'subsample': [0.8, 1],
    'alpha': [0.01, 0.1, 10]
}
g_search = GridSearchCV(xgb_model, param_grid, cv=ts_cv)
g_search.fit(x, y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=...
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'alpha': [0.01, 0.1, 10], 'learning_rate': [0.1, 0.01],
#                          'max_depth': [7, 9, 11, 13],
#                          'n_estimators': [300, 500, 700],
#                          'subsample': [0.8, 1]})

# %%
g_search.best_params_
# Out:
# {'alpha': 10,
#  'learning_rate': 0.1,
#  'max_depth': 13,
#  'n_estimators': 700,
#  'subsample': 0.8}

# %%
g_search.best_score_
# Out:
# 0.7476564977145832

# %%
import lightgbm as lgbm

lgbm_model = lgbm.LGBMRegressor()
lgbm_param_grid = {
    'objective': ['regression'],
    'max_depth': [5, 7, 9, 11, 13],
    'n_estimators': [300, 500, 700],
    'learning_rate': [0.1, 0.01],
    'subsample': [0.8, 1],
    'reg_alpha': [0, 0.1],
    'reg_lambda': [0, 0.1]
}
g_search = GridSearchCV(lgbm_model, lgbm_param_grid, cv=ts_cv)
g_search.fit(x, y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=LGBMRegressor(),
#              param_grid={'learning_rate': [0.1, 0.01],
#                          'max_depth': [5, 7, 9, 11, 13],
#                          'n_estimators': [300, 500, 700],
#                          'objective': ['regression'], 'reg_alpha': [0, 0.1],
#                          'reg_lambda': [0, 0.1], 'subsample': [0.8, 1]})

# %%
g_search.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 11,
#  'n_estimators': 500,
#  'objective': 'regression',
#  'reg_alpha': 0,
#  'reg_lambda': 0,
#  'subsample': 0.8}

# %%
g_search.best_score_
# Out:
# 0.6435545179117848

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor()
rf_param_grid = {
    'max_depth': [3, 5, 7, 9, 11],
    'n_estimators': [100, 300, 500, 600]
}
g_search = GridSearchCV(rf_model, rf_param_grid, cv=ts_cv)
g_search.fit(x, y)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [3, 5, 7, 9, 11],
#                          'n_estimators': [100, 300, 500, 600]})

# %%
g_search.best_params_
# Out:
# {'max_depth': 11, 'n_estimators': 100}

# %%
g_search.best_score_
# Out:
# 0.6483968340346882

# %% [markdown]
# ## Predict

# %%
train_pct = 0.80
train_size = int(x.shape[0] * train_pct)
test_size = x.shape[0] - train_size
x_train, y_train = x[0:train_size],y[0:train_size]
x_test, y_test = x[train_size:],y[train_size:]

# %%
x_train.shape
# Out:
# (1012, 40)

# %%
y_test.shape
# Out:
# (254,)

# %% [markdown]
# ### LGBM

# %%
lgbm_model = lgbm.LGBMRegressor(learning_rate=0.1,
                                max_depth=11,
                                n_estimators=500,
                                objective='regression',
                                reg_alpha=0,
                                reg_lambda=0,
                                subsample=0.8,
                                random_state=42)

# %%
lgbm_model.fit(x_train,y_train)
# Out:
# LGBMRegressor(max_depth=11, n_estimators=500, objective='regression',
#               random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8)

# %%
y_pred_lgbm = lgbm_model.predict(x_test)

# %%
plt.plot(y_pred_lgbm, label="LGBM estmated bmw_Close (y_test)")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test, y_pred_lgbm)
# Out:
# 1.080299135648912

# %%
ytr_pred_lgbm = lgbm_model.predict(x_train)

# %%
plt.plot(ytr_pred_lgbm, label="LGBM estmated bmw_Close (y_train)")
plt.plot(y_train, label="real bmw_Close (y_train)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_train, ytr_pred_lgbm)
# Out:
# 0.0015513080677646987

# %% [markdown]
# ### XGboosting

# %%
xgb_model = xgb.XGBRegressor(learning_rate=0.01,
                             max_depth=13,
                             n_estimators=500,
                             random_state=42)

# %%
xgb_model.fit(x_train,y_train)
y_pred_xgb = xgb_model.predict(x_test)

# %%
plt.plot(y_pred_xgb, label="XGboosting estmated bmw_Close (y_test)")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test, y_pred_xgb)
# Out:
# 1.0553124857696243

# %%
ytr_pred_xgb = xgb_model.predict(x_train)

plt.plot(ytr_pred_xgb, label="XGboosting estmated bmw_Close (y_train)")
plt.plot(y_train, label="real bmw_Close (y_train)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_train, ytr_pred_xgb)
# Out:
# 0.344438329001704

# %% [markdown]
# ### RF

# %%
rf_model = RandomForestRegressor(max_depth=11,
                                 n_estimators=100,
                                 random_state=42)

# %%
rf_model.fit(x_train,y_train)
y_pred_rf = rf_model.predict(x_test)

# %%
plt.plot(y_pred_rf, label="RF estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test, y_pred_rf)
# Out:
# 0.7745566166354589

# %%
ytr_pred_rf = rf_model.predict(x_train)

plt.plot(ytr_pred_rf, label="RF estmated bmw_Close (y_train)")
plt.plot(y_train, label="real bmw_Close (y_train)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_train, ytr_pred_rf)
# Out:
# 0.03393503625020336

# %% [markdown]
# ### Geometric Mean

# %%
from scipy.stats.mstats import gmean 
y_pred_gmean = gmean([y_pred_lgbm,y_pred_xgb,y_pred_rf])
ytr_pred_gmean = gmean([ytr_pred_lgbm,ytr_pred_xgb,ytr_pred_rf])

# %%
plt.plot(y_pred_gmean, label="gmean estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test, y_pred_gmean)
# Out:
# 0.5203685664142021

# %%
plt.plot(ytr_pred_gmean, label="gmean estmated bmw_Close")
plt.plot(y_train, label="real bmw_Close (y_train)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_train, ytr_pred_gmean)
# Out:
# 0.05122404758487901

# %% [markdown]
# ## Use gmean as feature to predict (Linear Regression)

# %%
X_test = y_pred_gmean
X_train = ytr_pred_gmean

# %%
X = np.concatenate((X_train,X_test))
X
# Out:
# array([77.30707044, 76.08577755, 76.83154383, ..., 78.07304147,
#        76.31356443, 77.97501281])

# %%
y
# Out:
# array([77.510002, 76.220001, 77.230003, ..., 77.43    , 76.980003,
#        76.800003])

# %%
from sklearn import linear_model

# %%
LR = linear_model.LinearRegression()
LR.fit(X.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
y_LR=LR.predict(X_test.reshape(-1,1))

# %%
mean_squared_error(y_test,y_LR)
# Out:
# 0.5557571247575337

# %% [markdown]
# ### Ridge

# %% [markdown]
# #### GridSearchCV

# %%
LRRegr = linear_model.Ridge(random_state=42)

# %%
param_grid = {'alpha': [0.01, 0.1, 10]}
g_search = GridSearchCV(LRRegr, param_grid)
g_search.fit(X.reshape(-1,1), y)
# Out:
# GridSearchCV(estimator=Ridge(random_state=42),
#              param_grid={'alpha': [0.01, 0.1, 10]})

# %%
g_search.best_params_
# Out:
# {'alpha': 0.01}

# %%
g_search.best_score_
# Out:
# 0.9979405021112264

# %% [markdown]
# #### Predict

# %%
Ridge_model = linear_model.Ridge(alpha=0.01, random_state=42)

# %%
Ridge_model.fit(X.reshape(-1,1), y)
# Out:
# Ridge(alpha=0.01, random_state=42)

# %%
y_pred_Ridge = Ridge_model.predict(X_test.reshape(-1,1))

# %%
mean_squared_error(y_test,y_pred_Ridge)
# Out:
# 0.5557570505544284

# %%
plt.plot(y_pred_Ridge, label="Ridge estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %% [markdown]
# ### Lasso

# %% [markdown]
# #### GridSearchCV

# %%
LLRegr = linear_model.Lasso(random_state=42)

# %%
param_grid = {'alpha': [0.01, 0.1, 10]}
g_search = GridSearchCV(LLRegr, param_grid)
g_search.fit(X.reshape(-1,1), y)
# Out:
# GridSearchCV(estimator=Lasso(random_state=42),
#              param_grid={'alpha': [0.01, 0.1, 10]})

# %%
g_search.best_params_
# Out:
# {'alpha': 0.01}

# %%
g_search.best_score_
# Out:
# 0.9979377439460618

# %% [markdown]
# #### Predict

# %%
Lasso_model = linear_model.Lasso(alpha=0.01, random_state=42)

# %%
Lasso_model.fit(X_train.reshape(-1,1), y_train)
# Out:
# Lasso(alpha=0.01, random_state=42)

# %%
y_pred_Lasso = Lasso_model.predict(X_test.reshape(-1,1))

# %%
mean_squared_error(y_test,y_pred_Lasso)
# Out:
# 0.5796762705440837

# %%
plt.plot(y_pred_Lasso, label="Lasso estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close (y_test)")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %% [markdown]
# ### GMean

# %%
yLR_pred_gmean = gmean([y_pred_Ridge,y_pred_Lasso])

# %%
plt.plot(yLR_pred_gmean, label="estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test,yLR_pred_gmean)
# Out:
# 0.5670313120259018

# %%
yall_pred_gmean = gmean([y_pred_Ridge,y_pred_Lasso,y_pred_lgbm,y_pred_xgb,y_pred_rf])

# %%
plt.plot(yall_pred_gmean, label="estmated bmw_Close")
plt.plot(y_test, label="real bmw_Close")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left', ncol=2)
plt.show()

# %%
mean_squared_error(y_test,yall_pred_gmean)
# Out:
# 0.5333527418745552
